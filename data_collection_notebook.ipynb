# %% [markdown]
# # Data Collection
# This notebook is meant for connecting to Sentinel Hub Python API to search Sentinel-2 collection and retrieve the corresponding satellite imagery.
#
# ! Important: This notebook was tested only in Colab enviroment. In order to execute certain cell other task have to be completed before hand including mounting the google drive.

# %%
# !pip install sentinelhub
# Out:
# Collecting sentinelhub
#   Downloading sentinelhub-3.9.1-py3-none-any.whl (244 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.4/244.4 kB 3.8 MB/s eta 0:00:00
# Collecting aenum>=2.1.4 (from sentinelhub)
#   Downloading aenum-3.1.15-py3-none-any.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.6/137.6 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (8.1.6)
# Collecting dataclasses-json (from sentinelhub)
#   Downloading dataclasses_json-0.5.14-py3-none-any.whl (26 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (1.23.5)
# Requirement already satisfied: oauthlib in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (3.2.2)
# Requirement already satisfied: pillow>=9.2.0 in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (9.4.0)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (3.6.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (2.8.2)
# Requirement already satisfied: requests-oauthlib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (1.3.1)
# Requirement already satisfied: requests>=2.27.0 in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (2.31.0)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (2.0.1)
# Requirement already satisfied: tifffile>=2020.9.30 in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (2023.8.12)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (2.0.1)
# Collecting tomli-w (from sentinelhub)
#   Downloading tomli_w-1.0.0-py3-none-any.whl (6.0 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (4.66.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from sentinelhub) (4.7.1)
# Collecting utm (from sentinelhub)
#   Downloading utm-0.7.0.tar.gz (8.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj>=2.2.0->sentinelhub) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.0->sentinelhub) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.0->sentinelhub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.0->sentinelhub) (2.0.4)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->sentinelhub)
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 3.3 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json->sentinelhub)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->sentinelhub) (1.16.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->sentinelhub) (23.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json->sentinelhub)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Building wheels for collected packages: utm
#   Building wheel for utm (setup.py) ... done
#   Created wheel for utm: filename=utm-0.7.0-py3-none-any.whl size=6085 sha256=7799139a168d517d8b26dba7b458a7ea73408662acfc16e545ebc7f657acfb2e
#   Stored in directory: /root/.cache/pip/wheels/2f/a1/c8/543df0e8f5e824c3e92a432e32deb9cd89ae686095ee8cfcbe
# Successfully built utm
# Installing collected packages: utm, aenum, tomli-w, mypy-extensions, marshmallow, typing-inspect, dataclasses-json, sentinelhub
# Successfully installed aenum-3.1.15 dataclasses-json-0.5.14 marshmallow-3.20.1 mypy-extensions-1.0.0 sentinelhub-3.9.1 tomli-w-1.0.0 typing-inspect-0.9.0 utm-0.7.0

# %%
from typing import Any, Optional, Tuple

import matplotlib.pyplot as plt
import numpy as np
import datetime
import os
import datetime as dt
import matplotlib.pyplot as plt
import numpy as np
import tarfile
import json
import cv2
from PIL import Image as im
import pandas as pd

from sentinelhub import (
    CRS,
    BBox,
    DataCollection,
    DownloadRequest,
    MimeType,
    SHConfig,
    MosaickingOrder,
    SentinelHubDownloadClient,
    SentinelHubRequest,
    bbox_to_dimensions,
    SentinelHubCatalog,
    filter_times
)

# %%
def plot_image(image, factor, clip_range = None, **kwargs: Any) -> None:
    """Utility function for plotting RGB images."""
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 15))
    if clip_range is not None:
        ax.imshow(np.clip(image * factor, *clip_range), **kwargs)
    else:
        ax.imshow(image * factor, **kwargs)
    ax.set_xticks([])
    ax.set_yticks([])

# %% [markdown]
# In order to access the data, a free new user profile has to be made in Sentinel Hub platform and a free trial account has to be activated. The next steps of where and which credential have to be obtain is detailed in their documentation page: https://sentinelhub-py.readthedocs.io/en/latest/configure.html#sentinel-hub-configuration

# %%
# Write your credentials here
CLIENT_ID = "<---sh_client_id---->"
CLIENT_SECRET = "<---sh_client_secret---->"
INSTANCE_ID = "<---instance_id---->"

config = SHConfig()
if CLIENT_ID and CLIENT_SECRET:
    config.instance_id = INSTANCE_ID
    config.sh_client_id = CLIENT_ID
    config.sh_client_secret = CLIENT_SECRET

# %%
# Define the time range and AOI
# Lyme Regis, South England
resolution = 1
landslide_bbox = BBox((-2.930574,50.727037,-2.904997,50.737625), crs=CRS.WGS84)
landslide_size = bbox_to_dimensions(landslide_bbox, resolution=resolution)
time_interval = "2015-01-01", "2022-12-31"

# %%
# Search the Sentinel-2 catalog and extract all the available dates that meet the criteria
# This request search for Sentinel-2 L1C product with less than 10% cloud coverage
# To search for Sentinel-2 L2A, replace the data collection to - DataCollection.SENTINEL2_L2A

# Returns product's ID, capture date and time, cloud coverage %

catalog = SentinelHubCatalog(config=config)
collections = catalog.get_collections()

search_iterator = catalog.search(
    DataCollection.SENTINEL2_L1C,
    bbox=landslide_bbox,
    time=time_interval,
    filter="eo:cloud_cover < 10",
    fields={"include": ["id", "properties.datetime", "properties.eo:cloud_cover"], "exclude": []},
)

results = list(search_iterator)
print("Total number of results:", len(results))

print("Catalog results: ")
results
# Out:
# Total number of results: 232
# Catalog results:
# [{'id': 'S2B_MSIL1C_20221220T112409_N0509_R037_T30UVB_20221220T120224',
#   'properties': {'datetime': '2022-12-20T11:27:06Z', 'eo:cloud_cover': 6.74}},
#  {'id': 'S2B_MSIL1C_20221220T112409_N0509_R037_T30UWB_20221220T120224',
#   'properties': {'datetime': '2022-12-20T11:27:02Z', 'eo:cloud_cover': 0.3}},
#  {'id': 'S2A_MSIL1C_20221215T112501_N0509_R037_T30UVB_20221215T132021',
#   'properties': {'datetime': '2022-12-15T11:27:07Z', 'eo:cloud_cover': 0.01}},
#  {'id': 'S2A_MSIL1C_20221215T112501_N0509_R037_T30UWB_20221215T132021',
#   'properties': {'datetime': '2022-12-15T11:27:02Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2B_MSIL1C_20221207T111339_N0509_R137_T30UVB_20221207T115404',
#   'properties': {'datetime': '2022-12-07T11:17:07Z', 'eo:cloud_cover': 1.67}},
#  {'id': 'S2B_MSIL1C_20221207T111339_N0509_R137_T30UWB_20221207T115404',
#   'properties': {'datetime': '2022-12-07T11:17:03Z', 'eo:cloud_cover': 0.3}},
#  {'id': 'S2A_MSIL1C_20221125T112411_N0400_R037_T30UVB_20221125T132446',
#   'properties': {'datetime': '2022-11-25T11:27:07Z', 'eo:cloud_cover': 6.54}},
#  {'id': 'S2A_MSIL1C_20221125T112411_N0400_R037_T30UWB_20221125T132446',
#   'properties': {'datetime': '2022-11-25T11:27:02Z', 'eo:cloud_cover': 1.34}},
#  {'id': 'S2A_MSIL1C_20221122T111401_N0400_R137_T30UVB_20221122T132445',
#   'properties': {'datetime': '2022-11-22T11:17:10Z', 'eo:cloud_cover': 9.55}},
#  {'id': 'S2A_MSIL1C_20221112T111321_N0400_R137_T30UWB_20221112T131032',
#   'properties': {'datetime': '2022-11-12T11:17:09Z', 'eo:cloud_cover': 0.86}},
#  {'id': 'S2A_MSIL1C_20221013T111011_N0400_R137_T30UVB_20221013T144920',
#   'properties': {'datetime': '2022-10-13T11:17:15Z', 'eo:cloud_cover': 6.41}},
#  {'id': 'S2B_MSIL1C_20221008T110839_N0400_R137_T30UWB_20221008T115207',
#   'properties': {'datetime': '2022-10-08T11:17:04Z', 'eo:cloud_cover': 4.85}},
#  {'id': 'S2A_MSIL1C_20220814T110631_N0400_R137_T30UVB_20220814T145019',
#   'properties': {'datetime': '2022-08-14T11:17:23Z', 'eo:cloud_cover': 7.04}},
#  {'id': 'S2B_MSIL1C_20220812T112119_N0400_R037_T30UVB_20220812T120820',
#   'properties': {'datetime': '2022-08-12T11:27:11Z', 'eo:cloud_cover': 0.99}},
#  {'id': 'S2B_MSIL1C_20220812T112119_N0400_R037_T30UWB_20220812T120820',
#   'properties': {'datetime': '2022-08-12T11:27:06Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2B_MSIL1C_20220809T110629_N0400_R137_T30UVB_20220809T115600',
#   'properties': {'datetime': '2022-08-09T11:17:14Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2B_MSIL1C_20220809T110629_N0400_R137_T30UWB_20220809T115600',
#   'properties': {'datetime': '2022-08-09T11:17:10Z', 'eo:cloud_cover': 0.01}},
#  {'id': 'S2A_MSIL1C_20220807T112131_N0400_R037_T30UVB_20220807T145932',
#   'properties': {'datetime': '2022-08-07T11:27:19Z', 'eo:cloud_cover': 0.65}},
#  {'id': 'S2A_MSIL1C_20220807T112131_N0400_R037_T30UWB_20220807T145932',
#   'properties': {'datetime': '2022-08-07T11:27:14Z', 'eo:cloud_cover': 2.19}},
#  {'id': 'S2A_MSIL1C_20220715T110631_N0400_R137_T30UWB_20220715T144925',
#   'properties': {'datetime': '2022-07-15T11:17:19Z', 'eo:cloud_cover': 7.01}},
#  {'id': 'S2A_MSIL1C_20220708T112131_N0400_R037_T30UWB_20220708T150142',
#   'properties': {'datetime': '2022-07-08T11:27:16Z', 'eo:cloud_cover': 0.15}},
#  {'id': 'S2B_MSIL1C_20220620T110629_N0400_R137_T30UVB_20220620T132116',
#   'properties': {'datetime': '2022-06-20T11:17:15Z', 'eo:cloud_cover': 1.86}},
#  {'id': 'S2B_MSIL1C_20220620T110629_N0400_R137_T30UWB_20220620T132116',
#   'properties': {'datetime': '2022-06-20T11:17:11Z', 'eo:cloud_cover': 0.39}},
#  {'id': 'S2A_MSIL1C_20220615T110631_N0400_R137_T30UWB_20220615T145154',
#   'properties': {'datetime': '2022-06-15T11:17:17Z', 'eo:cloud_cover': 9.72}},
#  {'id': 'S2A_MSIL1C_20220426T110631_N0400_R137_T30UVB_20220426T134313',
#   'properties': {'datetime': '2022-04-26T11:17:15Z', 'eo:cloud_cover': 0.05}},
#  {'id': 'S2A_MSIL1C_20220426T110631_N0400_R137_T30UWB_20220426T134313',
#   'properties': {'datetime': '2022-04-26T11:17:11Z', 'eo:cloud_cover': 2.04}},
#  {'id': 'S2B_MSIL1C_20220424T112109_N0400_R037_T30UWB_20220424T121455',
#   'properties': {'datetime': '2022-04-24T11:26:57Z', 'eo:cloud_cover': 5.4}},
#  {'id': 'S2A_MSIL1C_20220327T110701_N0400_R137_T30UVB_20220327T132412',
#   'properties': {'datetime': '2022-03-27T11:17:13Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2A_MSIL1C_20220327T110701_N0400_R137_T30UWB_20220327T132412',
#   'properties': {'datetime': '2022-03-27T11:17:09Z', 'eo:cloud_cover': 0.9}},
#  {'id': 'S2B_MSIL1C_20220325T112109_N0400_R037_T30UVB_20220325T120437',
#   'properties': {'datetime': '2022-03-25T11:27:05Z', 'eo:cloud_cover': 0.41}},
#  {'id': 'S2B_MSIL1C_20220325T112109_N0400_R037_T30UWB_20220325T120437',
#   'properties': {'datetime': '2022-03-25T11:27:00Z', 'eo:cloud_cover': 5.75}},
#  {'id': 'S2B_MSIL1C_20220322T110639_N0400_R137_T30UVB_20220322T121416',
#   'properties': {'datetime': '2022-03-22T11:17:08Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2B_MSIL1C_20220322T110639_N0400_R137_T30UWB_20220322T121416',
#   'properties': {'datetime': '2022-03-22T11:17:04Z', 'eo:cloud_cover': 0.4}},
#  {'id': 'S2A_MSIL1C_20220320T112121_N0400_R037_T30UVB_20220320T133840',
#   'properties': {'datetime': '2022-03-20T11:27:11Z', 'eo:cloud_cover': 0.93}},
#  {'id': 'S2A_MSIL1C_20220320T112121_N0400_R037_T30UWB_20220320T133840',
#   'properties': {'datetime': '2022-03-20T11:27:06Z', 'eo:cloud_cover': 0.52}},
#  {'id': 'S2A_MSIL1C_20220317T110811_N0400_R137_T30UVB_20220317T132718',
#   'properties': {'datetime': '2022-03-17T11:17:14Z', 'eo:cloud_cover': 3.0}},
#  {'id': 'S2A_MSIL1C_20220225T111051_N0400_R137_T30UWB_20220225T132829',
#   'properties': {'datetime': '2022-02-25T11:17:09Z', 'eo:cloud_cover': 4.66}},
#  {'id': 'S2B_MSIL1C_20220121T111249_N0301_R137_T30UVB_20220121T115523',
#   'properties': {'datetime': '2022-01-21T11:17:05Z', 'eo:cloud_cover': 0.05}},
#  {'id': 'S2B_MSIL1C_20220121T111249_N0301_R137_T30UWB_20220121T115523',
#   'properties': {'datetime': '2022-01-21T11:17:01Z', 'eo:cloud_cover': 1.04}},
#  {'id': 'S2B_MSIL1C_20220114T112329_N0301_R037_T30UVB_20220114T121513',
#   'properties': {'datetime': '2022-01-14T11:27:03Z', 'eo:cloud_cover': 0.72}},
#  {'id': 'S2B_MSIL1C_20220114T112329_N0301_R037_T30UWB_20220114T121513',
#   'properties': {'datetime': '2022-01-14T11:26:59Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2B_MSIL1C_20211205T112339_N0301_R037_T30UVB_20211205T121503',
#   'properties': {'datetime': '2021-12-05T11:27:03Z', 'eo:cloud_cover': 8.16}},
#  {'id': 'S2B_MSIL1C_20211202T111329_N0301_R137_T30UVB_20211202T120633',
#   'properties': {'datetime': '2021-12-02T11:17:06Z', 'eo:cloud_cover': 1.27}},
#  {'id': 'S2B_MSIL1C_20211202T111329_N0301_R137_T30UWB_20211202T120633',
#   'properties': {'datetime': '2021-12-02T11:17:02Z', 'eo:cloud_cover': 0.46}},
#  {'id': 'S2B_MSIL1C_20211125T112319_N0301_R037_T30UVB_20211125T120515',
#   'properties': {'datetime': '2021-11-25T11:27:03Z', 'eo:cloud_cover': 1.67}},
#  {'id': 'S2B_MSIL1C_20211125T112319_N0301_R037_T30UWB_20211125T120515',
#   'properties': {'datetime': '2021-11-25T11:26:59Z', 'eo:cloud_cover': 0.06}},
#  {'id': 'S2B_MSIL1C_20211122T111259_N0301_R137_T30UVB_20211122T120855',
#   'properties': {'datetime': '2021-11-22T11:17:07Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2B_MSIL1C_20211122T111259_N0301_R137_T30UWB_20211122T120855',
#   'properties': {'datetime': '2021-11-22T11:17:03Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2A_MSIL1C_20211021T112121_N0301_R037_T30UWB_20211021T133204',
#   'properties': {'datetime': '2021-10-21T11:27:08Z', 'eo:cloud_cover': 0.26}},
#  {'id': 'S2B_MSIL1C_20210926T112109_N0301_R037_T30UWB_20210926T120408',
#   'properties': {'datetime': '2021-09-26T11:27:01Z', 'eo:cloud_cover': 9.2}},
#  {'id': 'S2B_MSIL1C_20210824T110619_N0301_R137_T30UVB_20210824T120705',
#   'properties': {'datetime': '2021-08-24T11:17:09Z', 'eo:cloud_cover': 6.37}},
#  {'id': 'S2A_MSIL1C_20210720T110621_N0301_R137_T30UWB_20210720T132532',
#   'properties': {'datetime': '2021-07-20T11:17:10Z', 'eo:cloud_cover': 2.09}},
#  {'id': 'S2B_MSIL1C_20210718T112119_N0301_R037_T30UVB_20210718T121443',
#   'properties': {'datetime': '2021-07-18T11:27:09Z', 'eo:cloud_cover': 2.5}},
#  {'id': 'S2B_MSIL1C_20210718T112119_N0301_R037_T30UWB_20210718T121443',
#   'properties': {'datetime': '2021-07-18T11:27:05Z', 'eo:cloud_cover': 0.05}},
#  {'id': 'S2A_MSIL1C_20210613T112111_N0300_R037_T30UVB_20210613T133154',
#   'properties': {'datetime': '2021-06-13T11:27:08Z', 'eo:cloud_cover': 0.05}},
#  {'id': 'S2A_MSIL1C_20210613T112111_N0300_R037_T30UWB_20210613T133154',
#   'properties': {'datetime': '2021-06-13T11:27:03Z', 'eo:cloud_cover': 2.28}},
#  {'id': 'S2B_MSIL1C_20210605T110619_N0300_R137_T30UWB_20210605T132757',
#   'properties': {'datetime': '2021-06-05T11:17:07Z', 'eo:cloud_cover': 4.96}},
#  {'id': 'S2A_MSIL1C_20210531T110621_N0300_R137_T30UVB_20210531T132211',
#   'properties': {'datetime': '2021-05-31T11:17:11Z', 'eo:cloud_cover': 2.06}},
#  {'id': 'S2A_MSIL1C_20210531T110621_N0300_R137_T30UWB_20210531T132211',
#   'properties': {'datetime': '2021-05-31T11:17:07Z', 'eo:cloud_cover': 0.28}},
#  {'id': 'S2B_MSIL1C_20210519T112119_N0300_R037_T30UVB_20210519T133308',
#   'properties': {'datetime': '2021-05-19T11:27:07Z', 'eo:cloud_cover': 9.02}},
#  {'id': 'S2A_MSIL1C_20210424T112111_N0300_R037_T30UVB_20210424T132925',
#   'properties': {'datetime': '2021-04-24T11:27:04Z', 'eo:cloud_cover': 2.82}},
#  {'id': 'S2A_MSIL1C_20210424T112111_N0300_R037_T30UWB_20210424T132925',
#   'properties': {'datetime': '2021-04-24T11:26:59Z', 'eo:cloud_cover': 1.59}},
#  {'id': 'S2B_MSIL1C_20210419T112109_N0300_R037_T30UVB_20210419T122653',
#   'properties': {'datetime': '2021-04-19T11:27:02Z', 'eo:cloud_cover': 8.86}},
#  {'id': 'S2A_MSIL1C_20210404T112111_N0300_R037_T30UVB_20210404T133105',
#   'properties': {'datetime': '2021-04-04T11:27:04Z', 'eo:cloud_cover': 0.04}},
#  {'id': 'S2A_MSIL1C_20210404T112111_N0300_R037_T30UWB_20210404T133105',
#   'properties': {'datetime': '2021-04-04T11:26:59Z', 'eo:cloud_cover': 3.17}},
#  {'id': 'S2B_MSIL1C_20210307T110819_N0209_R137_T30UVB_20210307T132534',
#   'properties': {'datetime': '2021-03-07T11:17:09Z', 'eo:cloud_cover': 9.02}},
#  {'id': 'S2B_MSIL1C_20210228T112109_N0209_R037_T30UVB_20210228T122718',
#   'properties': {'datetime': '2021-02-28T11:27:06Z', 'eo:cloud_cover': 0.06}},
#  {'id': 'S2B_MSIL1C_20210228T112109_N0209_R037_T30UWB_20210228T122718',
#   'properties': {'datetime': '2021-02-28T11:27:02Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2B_MSIL1C_20201227T111359_N0209_R137_T30UVB_20201227T122128',
#   'properties': {'datetime': '2020-12-27T11:17:08Z', 'eo:cloud_cover': 4.68}},
#  {'id': 'S2B_MSIL1C_20201227T111359_N0209_R137_T30UWB_20201227T122128',
#   'properties': {'datetime': '2020-12-27T11:17:04Z', 'eo:cloud_cover': 4.62}},
#  {'id': 'S2B_MSIL1C_20201220T112359_N0209_R037_T30UWB_20201220T122736',
#   'properties': {'datetime': '2020-12-20T11:26:59Z', 'eo:cloud_cover': 7.46}},
#  {'id': 'S2A_MSIL1C_20201212T111451_N0209_R137_T30UWB_20201212T132354',
#   'properties': {'datetime': '2020-12-12T11:17:03Z', 'eo:cloud_cover': 1.29}},
#  {'id': 'S2A_MSIL1C_20201112T111321_N0209_R137_T30UVB_20201112T132551',
#   'properties': {'datetime': '2020-11-12T11:17:14Z', 'eo:cloud_cover': 2.53}},
#  {'id': 'S2A_MSIL1C_20201105T112251_N0209_R037_T30UVB_20201105T133204',
#   'properties': {'datetime': '2020-11-05T11:27:12Z', 'eo:cloud_cover': 7.21}},
#  {'id': 'S2A_MSIL1C_20201105T112251_N0209_R037_T30UWB_20201105T133204',
#   'properties': {'datetime': '2020-11-05T11:27:07Z', 'eo:cloud_cover': 0.89}},
#  {'id': 'S2A_MSIL1C_20200926T112121_N0209_R037_T30UVB_20200926T133546',
#   'properties': {'datetime': '2020-09-26T11:27:13Z', 'eo:cloud_cover': 2.92}},
#  {'id': 'S2A_MSIL1C_20200926T112121_N0209_R037_T30UWB_20200926T133546',
#   'properties': {'datetime': '2020-09-26T11:27:08Z', 'eo:cloud_cover': 2.9}},
#  {'id': 'S2B_MSIL1C_20200921T112119_N0209_R037_T30UVB_20200921T123213',
#   'properties': {'datetime': '2020-09-21T11:27:10Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2B_MSIL1C_20200921T112119_N0209_R037_T30UWB_20200921T123213',
#   'properties': {'datetime': '2020-09-21T11:27:05Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2B_MSIL1C_20200918T110639_N0209_R137_T30UVB_20200918T123523',
#   'properties': {'datetime': '2020-09-18T11:17:12Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2B_MSIL1C_20200918T110639_N0209_R137_T30UWB_20200918T123523',
#   'properties': {'datetime': '2020-09-18T11:17:08Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2A_MSIL1C_20200916T112121_N0209_R037_T30UWB_20200916T133804',
#   'properties': {'datetime': '2020-09-16T11:27:07Z', 'eo:cloud_cover': 0.82}},
#  {'id': 'S2A_MSIL1C_20200913T110701_N0209_R137_T30UVB_20200913T132524',
#   'properties': {'datetime': '2020-09-13T11:17:14Z', 'eo:cloud_cover': 0.57}},
#  {'id': 'S2A_MSIL1C_20200913T110701_N0209_R137_T30UWB_20200913T132524',
#   'properties': {'datetime': '2020-09-13T11:17:10Z', 'eo:cloud_cover': 0.16}},
#  {'id': 'S2B_MSIL1C_20200730T110619_N0209_R137_T30UVB_20200730T122556',
#   'properties': {'datetime': '2020-07-30T11:17:13Z', 'eo:cloud_cover': 0.5}},
#  {'id': 'S2B_MSIL1C_20200730T110619_N0209_R137_T30UWB_20200730T122556',
#   'properties': {'datetime': '2020-07-30T11:17:09Z', 'eo:cloud_cover': 5.78}},
#  {'id': 'S2B_MSIL1C_20200720T110619_N0209_R137_T30UVB_20200720T122229',
#   'properties': {'datetime': '2020-07-20T11:17:12Z', 'eo:cloud_cover': 0.71}},
#  {'id': 'S2A_MSIL1C_20200625T110631_N0209_R137_T30UVB_20200625T114101',
#   'properties': {'datetime': '2020-06-25T11:17:16Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2A_MSIL1C_20200625T110631_N0209_R137_T30UWB_20200625T114101',
#   'properties': {'datetime': '2020-06-25T11:17:12Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2B_MSIL1C_20200623T112119_N0209_R037_T30UVB_20200623T132800',
#   'properties': {'datetime': '2020-06-23T11:27:10Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2B_MSIL1C_20200623T112119_N0209_R037_T30UWB_20200623T132800',
#   'properties': {'datetime': '2020-06-23T11:27:05Z', 'eo:cloud_cover': 0.01}},
#  {'id': 'S2B_MSIL1C_20200531T110619_N0209_R137_T30UVB_20200531T122354',
#   'properties': {'datetime': '2020-05-31T11:17:12Z', 'eo:cloud_cover': 4.9}},
#  {'id': 'S2B_MSIL1C_20200531T110619_N0209_R137_T30UWB_20200531T122354',
#   'properties': {'datetime': '2020-05-31T11:17:08Z', 'eo:cloud_cover': 1.66}},
#  {'id': 'S2A_MSIL1C_20200529T112121_N0209_R037_T30UVB_20200529T114450',
#   'properties': {'datetime': '2020-05-29T11:27:14Z', 'eo:cloud_cover': 0.06}},
#  {'id': 'S2A_MSIL1C_20200529T112121_N0209_R037_T30UWB_20200529T114450',
#   'properties': {'datetime': '2020-05-29T11:27:09Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2A_MSIL1C_20200526T110631_N0209_R137_T30UVB_20200526T113427',
#   'properties': {'datetime': '2020-05-26T11:17:20Z', 'eo:cloud_cover': 7.68}},
#  {'id': 'S2A_MSIL1C_20200526T110631_N0209_R137_T30UWB_20200526T113427',
#   'properties': {'datetime': '2020-05-26T11:17:18Z', 'eo:cloud_cover': 1.76}},
#  {'id': 'S2B_MSIL1C_20200524T112119_N0209_R037_T30UWB_20200524T123106',
#   'properties': {'datetime': '2020-05-24T11:27:04Z', 'eo:cloud_cover': 8.37}},
#  {'id': 'S2B_MSIL1C_20200521T110619_N0209_R137_T30UVB_20200521T122737',
#   'properties': {'datetime': '2020-05-21T11:17:11Z', 'eo:cloud_cover': 2.03}},
#  {'id': 'S2B_MSIL1C_20200521T110619_N0209_R137_T30UWB_20200521T122737',
#   'properties': {'datetime': '2020-05-21T11:17:06Z', 'eo:cloud_cover': 0.17}},
#  {'id': 'S2B_MSIL1C_20200514T112109_N0209_R037_T30UVB_20200514T124356',
#   'properties': {'datetime': '2020-05-14T11:27:07Z', 'eo:cloud_cover': 4.4}},
#  {'id': 'S2A_MSIL1C_20200506T110621_N0209_R137_T30UVB_20200506T145647',
#   'properties': {'datetime': '2020-05-06T11:17:14Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2A_MSIL1C_20200506T110621_N0209_R137_T30UWB_20200506T145647',
#   'properties': {'datetime': '2020-05-06T11:17:10Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2A_MSIL1C_20200426T110621_N0209_R137_T30UWB_20200426T115636',
#   'properties': {'datetime': '2020-04-26T11:17:08Z', 'eo:cloud_cover': 0.95}},
#  {'id': 'S2B_MSIL1C_20200421T110619_N0209_R137_T30UWB_20200421T123240',
#   'properties': {'datetime': '2020-04-21T11:17:01Z', 'eo:cloud_cover': 1.6}},
#  {'id': 'S2A_MSIL1C_20200419T112111_N0209_R037_T30UWB_20200419T120107',
#   'properties': {'datetime': '2020-04-19T11:27:03Z', 'eo:cloud_cover': 0.04}},
#  {'id': 'S2B_MSIL1C_20200414T112109_N0209_R037_T30UVB_20200414T123647',
#   'properties': {'datetime': '2020-04-14T11:27:03Z', 'eo:cloud_cover': 3.21}},
#  {'id': 'S2B_MSIL1C_20200414T112109_N0209_R037_T30UWB_20200414T123647',
#   'properties': {'datetime': '2020-04-14T11:26:59Z', 'eo:cloud_cover': 1.54}},
#  {'id': 'S2B_MSIL1C_20200411T110619_N0209_R137_T30UWB_20200411T130947',
#   'properties': {'datetime': '2020-04-11T11:17:02Z', 'eo:cloud_cover': 3.18}},
#  {'id': 'S2B_MSIL1C_20200404T112109_N0209_R037_T30UWB_20200404T132118',
#   'properties': {'datetime': '2020-04-04T11:27:00Z', 'eo:cloud_cover': 5.34}},
#  {'id': 'S2A_MSIL1C_20200327T110651_N0209_R137_T30UVB_20200327T115046',
#   'properties': {'datetime': '2020-03-27T11:17:06Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2A_MSIL1C_20200327T110651_N0209_R137_T30UWB_20200327T115046',
#   'properties': {'datetime': '2020-03-27T11:17:02Z', 'eo:cloud_cover': 0.32}},
#  {'id': 'S2B_MSIL1C_20200325T112109_N0209_R037_T30UVB_20200325T142047',
#   'properties': {'datetime': '2020-03-25T11:27:05Z', 'eo:cloud_cover': 3.33}},
#  {'id': 'S2B_MSIL1C_20200325T112109_N0209_R037_T30UWB_20200325T142047',
#   'properties': {'datetime': '2020-03-25T11:27:01Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2B_MSIL1C_20200322T110639_N0209_R137_T30UVB_20200322T123116',
#   'properties': {'datetime': '2020-03-22T11:17:08Z', 'eo:cloud_cover': 0.01}},
#  {'id': 'S2B_MSIL1C_20200302T110849_N0209_R137_T30UWB_20200302T131500',
#   'properties': {'datetime': '2020-03-02T11:17:04Z', 'eo:cloud_cover': 8.27}},
#  {'id': 'S2B_MSIL1C_20200115T112319_N0208_R037_T30UVB_20200115T115204',
#   'properties': {'datetime': '2020-01-15T11:27:02Z', 'eo:cloud_cover': 3.02}},
#  {'id': 'S2B_MSIL1C_20191203T111329_N0208_R137_T30UWB_20191203T114224',
#   'properties': {'datetime': '2019-12-03T11:17:00Z', 'eo:cloud_cover': 0.9}},
#  {'id': 'S2A_MSIL1C_20191118T111341_N0208_R137_T30UWB_20191118T114037',
#   'properties': {'datetime': '2019-11-18T11:17:08Z', 'eo:cloud_cover': 0.16}},
#  {'id': 'S2A_MSIL1C_20191108T111251_N0208_R137_T30UVB_20191108T115002',
#   'properties': {'datetime': '2019-11-08T11:17:13Z', 'eo:cloud_cover': 9.78}},
#  {'id': 'S2B_MSIL1C_20191103T111129_N0208_R137_T30UVB_20191103T113925',
#   'properties': {'datetime': '2019-11-03T11:17:11Z', 'eo:cloud_cover': 4.97}},
#  {'id': 'S2A_MSIL1C_20191002T112121_N0208_R037_T30UWB_20191002T115438',
#   'properties': {'datetime': '2019-10-02T11:27:05Z', 'eo:cloud_cover': 4.85}},
#  {'id': 'S2A_MSIL1C_20190919T110721_N0208_R137_T30UVB_20190919T131545',
#   'properties': {'datetime': '2019-09-19T11:17:10Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2A_MSIL1C_20190919T110721_N0208_R137_T30UWB_20190919T131545',
#   'properties': {'datetime': '2019-09-19T11:17:06Z', 'eo:cloud_cover': 0.06}},
#  {'id': 'S2B_MSIL1C_20190917T112119_N0208_R037_T30UVB_20190917T132014',
#   'properties': {'datetime': '2019-09-17T11:27:07Z', 'eo:cloud_cover': 0.27}},
#  {'id': 'S2B_MSIL1C_20190917T112119_N0208_R037_T30UWB_20190917T132014',
#   'properties': {'datetime': '2019-09-17T11:27:02Z', 'eo:cloud_cover': 0.05}},
#  {'id': 'S2B_MSIL1C_20190914T110649_N0208_R137_T30UVB_20190914T131102',
#   'properties': {'datetime': '2019-09-14T11:17:10Z', 'eo:cloud_cover': 0.12}},
#  {'id': 'S2B_MSIL1C_20190914T110649_N0208_R137_T30UWB_20190914T131102',
#   'properties': {'datetime': '2019-09-14T11:17:06Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2B_MSIL1C_20190825T110629_N0208_R137_T30UVB_20190825T122017',
#   'properties': {'datetime': '2019-08-25T11:17:15Z', 'eo:cloud_cover': 0.04}},
#  {'id': 'S2B_MSIL1C_20190825T110629_N0208_R137_T30UWB_20190825T122017',
#   'properties': {'datetime': '2019-08-25T11:17:11Z', 'eo:cloud_cover': 6.31}},
#  {'id': 'S2A_MSIL1C_20190823T112121_N0208_R037_T30UVB_20190823T115457',
#   'properties': {'datetime': '2019-08-23T11:27:09Z', 'eo:cloud_cover': 0.55}},
#  {'id': 'S2A_MSIL1C_20190823T112121_N0208_R037_T30UWB_20190823T115457',
#   'properties': {'datetime': '2019-08-23T11:27:05Z', 'eo:cloud_cover': 1.91}},
#  {'id': 'S2B_MSIL1C_20190729T112119_N0208_R037_T30UWB_20190729T132407',
#   'properties': {'datetime': '2019-07-29T11:27:11Z', 'eo:cloud_cover': 9.76}},
#  {'id': 'S2A_MSIL1C_20190724T112121_N0208_R037_T30UWB_20190724T115917',
#   'properties': {'datetime': '2019-07-24T11:27:08Z', 'eo:cloud_cover': 5.58}},
#  {'id': 'S2B_MSIL1C_20190716T110629_N0208_R137_T30UVB_20190716T121832',
#   'properties': {'datetime': '2019-07-16T11:17:19Z', 'eo:cloud_cover': 8.72}},
#  {'id': 'S2B_MSIL1C_20190706T110629_N0207_R137_T30UVB_20190706T121957',
#   'properties': {'datetime': '2019-07-06T11:17:19Z', 'eo:cloud_cover': 7.41}},
#  {'id': 'S2A_MSIL1C_20190704T112121_N0207_R037_T30UVB_20190704T132434',
#   'properties': {'datetime': '2019-07-04T11:27:12Z', 'eo:cloud_cover': 6.04}},
#  {'id': 'S2B_MSIL1C_20190629T112119_N0207_R037_T30UWB_20190629T123210',
#   'properties': {'datetime': '2019-06-29T11:27:11Z', 'eo:cloud_cover': 1.25}},
#  {'id': 'S2B_MSIL1C_20190420T112119_N0207_R037_T30UVB_20190420T132504',
#   'properties': {'datetime': '2019-04-20T11:29:56Z', 'eo:cloud_cover': 8.47}},
#  {'id': 'S2B_MSIL1C_20190328T111049_N0207_R137_T30UVB_20190328T145454',
#   'properties': {'datetime': '2019-03-28T11:20:54Z', 'eo:cloud_cover': 1.18}},
#  {'id': 'S2B_MSIL1C_20190328T111049_N0207_R137_T30UWB_20190328T145454',
#   'properties': {'datetime': '2019-03-28T11:20:11Z', 'eo:cloud_cover': 8.79}},
#  {'id': 'S2A_MSIL1C_20190326T112111_N0207_R037_T30UVB_20190326T182129',
#   'properties': {'datetime': '2019-03-26T11:27:09Z', 'eo:cloud_cover': 5.29}},
#  {'id': 'S2B_MSIL1C_20190226T111049_N0207_R137_T30UWB_20190226T163538',
#   'properties': {'datetime': '2019-02-26T11:23:40Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2B_MSIL1C_20190226T111049_N0207_R137_T30UVB_20190226T163538',
#   'properties': {'datetime': '2019-02-26T11:17:13Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2A_MSIL1C_20190224T112111_N0207_R037_T30UWB_20190224T133506',
#   'properties': {'datetime': '2019-02-24T11:43:01Z', 'eo:cloud_cover': 0.05}},
#  {'id': 'S2A_MSIL1C_20190224T112111_N0207_R037_T30UVB_20190224T133506',
#   'properties': {'datetime': '2019-02-24T11:36:54Z', 'eo:cloud_cover': 2.12}},
#  {'id': 'S2A_MSIL1C_20190214T112151_N0207_R037_T30UVB_20190214T114618',
#   'properties': {'datetime': '2019-02-14T11:27:04Z', 'eo:cloud_cover': 7.47}},
#  {'id': 'S2B_MSIL1C_20190117T111409_N0207_R137_T30UVB_20190117T114358',
#   'properties': {'datetime': '2019-01-17T11:17:10Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2B_MSIL1C_20190117T111409_N0207_R137_T30UWB_20190117T114358',
#   'properties': {'datetime': '2019-01-17T11:17:06Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2A_MSIL1C_20181126T112411_N0207_R037_T30UWB_20181126T123407',
#   'properties': {'datetime': '2018-11-26T11:26:55Z', 'eo:cloud_cover': 5.48}},
#  {'id': 'S2B_MSIL1C_20181118T111339_N0207_R137_T30UVB_20181118T131842',
#   'properties': {'datetime': '2018-11-18T11:17:07Z', 'eo:cloud_cover': 0.24}},
#  {'id': 'S2B_MSIL1C_20181118T111339_N0207_R137_T30UWB_20181118T131842',
#   'properties': {'datetime': '2018-11-18T11:17:03Z', 'eo:cloud_cover': 0.02}},
#  {'id': 'S2B_MSIL1C_20181111T112309_N0207_R037_T30UVB_20181111T132603',
#   'properties': {'datetime': '2018-11-11T11:27:05Z', 'eo:cloud_cover': 6.65}},
#  {'id': 'S2B_MSIL1C_20181029T111149_N0206_R137_T30UVB_20181029T131331',
#   'properties': {'datetime': '2018-10-29T11:11:52Z', 'eo:cloud_cover': 0.66}},
#  {'id': 'S2B_MSIL1C_20181029T111149_N0206_R137_T30UWB_20181029T131331',
#   'properties': {'datetime': '2018-10-29T11:11:52Z', 'eo:cloud_cover': 0.55}},
#  {'id': 'S2B_MSIL1C_20181022T112119_N0206_R037_T30UWB_20181022T134018',
#   'properties': {'datetime': '2018-10-22T11:21:13Z', 'eo:cloud_cover': 0.35}},
#  {'id': 'S2B_MSIL1C_20181022T112119_N0206_R037_T30UVB_20181022T134018',
#   'properties': {'datetime': '2018-10-22T11:21:13Z', 'eo:cloud_cover': 0.03}},
#  {'id': 'S2B_MSIL1C_20181019T111049_N0206_R137_T30UWB_20181019T131719',
#   'properties': {'datetime': '2018-10-19T11:10:50Z', 'eo:cloud_cover': 0.05}},
#  {'id': 'S2B_MSIL1C_20181019T111049_N0206_R137_T30UVB_20181019T131719',
#   'properties': {'datetime': '2018-10-19T11:10:50Z', 'eo:cloud_cover': 0.16}},
#  {'id': 'S2B_MSIL1C_20181009T110939_N0206_R137_T30UWB_20181009T131802',
#   'properties': {'datetime': '2018-10-09T11:09:42Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2B_MSIL1C_20181009T110939_N0206_R137_T30UVB_20181009T131802',
#   'properties': {'datetime': '2018-10-09T11:09:42Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2A_MSIL1C_20180927T112111_N0206_R037_T30UVB_20180927T114831',
#   'properties': {'datetime': '2018-09-27T11:23:30Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2A_MSIL1C_20180927T112111_N0206_R037_T30UWB_20180927T114831',
#   'properties': {'datetime': '2018-09-27T11:23:30Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2A_MSIL1C_20180924T110801_N0206_R137_T30UVB_20180924T133215',
#   'properties': {'datetime': '2018-09-24T11:14:16Z', 'eo:cloud_cover': 5.94}},
#  {'id': 'S2B_MSIL1C_20180909T110609_N0206_R137_T30UVB_20180909T150925',
#   'properties': {'datetime': '2018-09-09T11:13:19Z', 'eo:cloud_cover': 1.83}},
#  {'id': 'S2A_MSIL1C_20180825T110621_N0206_R137_T30UVB_20180825T133902',
#   'properties': {'datetime': '2018-08-25T11:16:24Z', 'eo:cloud_cover': 4.54}},
#  {'id': 'S2A_MSIL1C_20180805T110621_N0206_R137_T30UWB_20180805T133536',
#   'properties': {'datetime': '2018-08-05T11:15:14Z', 'eo:cloud_cover': 8.49}},
#  {'id': 'S2A_MSIL1C_20180805T110621_N0206_R137_T30UVB_20180805T133536',
#   'properties': {'datetime': '2018-08-05T11:15:14Z', 'eo:cloud_cover': 0.23}},
#  {'id': 'S2B_MSIL1C_20180731T110619_N0206_R137_T30UVB_20180731T152032',
#   'properties': {'datetime': '2018-07-31T11:14:37Z', 'eo:cloud_cover': 4.66}},
#  {'id': 'S2A_MSIL1C_20180726T110621_N0206_R137_T30UVB_20180726T132819',
#   'properties': {'datetime': '2018-07-26T11:16:15Z', 'eo:cloud_cover': 9.4}},
#  {'id': 'S2B_MSIL1C_20180724T112109_N0206_R037_T30UWB_20180724T150820',
#   'properties': {'datetime': '2018-07-24T11:23:35Z', 'eo:cloud_cover': 9.79}},
#  {'id': 'S2B_MSIL1C_20180721T110619_N0206_R137_T30UVB_20180721T150056',
#   'properties': {'datetime': '2018-07-21T11:09:39Z', 'eo:cloud_cover': 7.33}},
#  {'id': 'S2A_MSIL1C_20180709T112121_N0206_R037_T30UVB_20180709T133743',
#   'properties': {'datetime': '2018-07-09T11:24:55Z', 'eo:cloud_cover': 5.38}},
#  {'id': 'S2A_MSIL1C_20180706T110621_N0206_R137_T30UVB_20180706T132104',
#   'properties': {'datetime': '2018-07-06T11:09:18Z', 'eo:cloud_cover': 9.08}},
#  {'id': 'S2A_MSIL1C_20180629T112111_N0206_R037_T30UWB_20180629T151157',
#   'properties': {'datetime': '2018-06-29T11:25:37Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2A_MSIL1C_20180629T112111_N0206_R037_T30UVB_20180629T151157',
#   'properties': {'datetime': '2018-06-29T11:25:37Z', 'eo:cloud_cover': 0.43}},
#  {'id': 'S2A_MSIL1C_20180626T110621_N0206_R137_T30UWB_20180626T113415',
#   'properties': {'datetime': '2018-06-26T11:14:13Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2A_MSIL1C_20180626T110621_N0206_R137_T30UVB_20180626T113415',
#   'properties': {'datetime': '2018-06-26T11:14:13Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2B_MSIL1C_20180611T110619_N0206_R137_T30UVB_20180611T170311',
#   'properties': {'datetime': '2018-06-11T11:07:04Z', 'eo:cloud_cover': 3.89}},
#  {'id': 'S2B_MSIL1C_20180611T110619_N0206_R137_T30UWB_20180611T170311',
#   'properties': {'datetime': '2018-06-11T11:07:04Z', 'eo:cloud_cover': 2.17}},
#  {'id': 'S2B_MSIL1C_20180515T112109_N0206_R037_T30UVB_20180515T135621',
#   'properties': {'datetime': '2018-05-15T11:21:16Z', 'eo:cloud_cover': 8.17}},
#  {'id': 'S2B_MSIL1C_20180515T112109_N0206_R037_T30UWB_20180515T135621',
#   'properties': {'datetime': '2018-05-15T11:21:16Z', 'eo:cloud_cover': 0.07}},
#  {'id': 'S2A_MSIL1C_20180507T110621_N0206_R137_T30UWB_20180507T131836',
#   'properties': {'datetime': '2018-05-07T11:08:35Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2A_MSIL1C_20180507T110621_N0206_R137_T30UVB_20180507T131836',
#   'properties': {'datetime': '2018-05-07T11:08:35Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2B_MSIL1C_20180505T112109_N0206_R037_T30UVB_20180505T135659',
#   'properties': {'datetime': '2018-05-05T11:23:04Z', 'eo:cloud_cover': 2.75}},
#  {'id': 'S2B_MSIL1C_20180505T112109_N0206_R037_T30UWB_20180505T135659',
#   'properties': {'datetime': '2018-05-05T11:23:04Z', 'eo:cloud_cover': 2.78}},
#  {'id': 'S2A_MSIL1C_20180420T112121_N0206_R037_T30UWB_20180420T132427',
#   'properties': {'datetime': '2018-04-20T11:26:11Z', 'eo:cloud_cover': 4.53}},
#  {'id': 'S2B_MSIL1C_20180224T112109_N0206_R037_T30UWB_20180224T164834',
#   'properties': {'datetime': '2018-02-24T11:22:28Z', 'eo:cloud_cover': 0.01}},
#  {'id': 'S2B_MSIL1C_20180224T112109_N0206_R037_T30UVB_20180224T164834',
#   'properties': {'datetime': '2018-02-24T11:22:28Z', 'eo:cloud_cover': 0.12}},
#  {'id': 'S2A_MSIL1C_20180110T112431_N0206_R037_T30UWB_20180110T132415',
#   'properties': {'datetime': '2018-01-10T11:24:27Z', 'eo:cloud_cover': 3.63}},
#  {'id': 'S2A_MSIL1C_20171218T111451_N0206_R137_T30UVB_20171218T131138',
#   'properties': {'datetime': '2017-12-18T11:14:49Z', 'eo:cloud_cover': 2.68}},
#  {'id': 'S2A_MSIL1C_20171218T111451_N0206_R137_T30UWB_20171218T131138',
#   'properties': {'datetime': '2017-12-18T11:14:49Z', 'eo:cloud_cover': 4.82}},
#  {'id': 'S2B_MSIL1C_20171216T112449_N0206_R037_T30UWB_20171216T132611',
#   'properties': {'datetime': '2017-12-16T11:24:45Z', 'eo:cloud_cover': 4.48}},
#  {'id': 'S2B_MSIL1C_20171216T112449_N0206_R037_T30UVB_20171216T132611',
#   'properties': {'datetime': '2017-12-16T11:24:45Z', 'eo:cloud_cover': 5.7}},
#  {'id': 'S2A_MSIL1C_20171208T111441_N0206_R137_T30UVB_20171208T113351',
#   'properties': {'datetime': '2017-12-08T11:15:49Z', 'eo:cloud_cover': 7.4}},
#  {'id': 'S2A_MSIL1C_20171201T112431_N0206_R037_T30UWB_20171201T114409',
#   'properties': {'datetime': '2017-12-01T11:26:42Z', 'eo:cloud_cover': 1.58}},
#  {'id': 'S2A_MSIL1C_20171201T112431_N0206_R037_T30UVB_20171201T114409',
#   'properties': {'datetime': '2017-12-01T11:26:42Z', 'eo:cloud_cover': 2.22}},
#  {'id': 'S2A_MSIL1C_20171128T111411_N0206_R137_T30UWB_20171128T130743',
#   'properties': {'datetime': '2017-11-28T11:14:12Z', 'eo:cloud_cover': 2.11}},
#  {'id': 'S2A_MSIL1C_20171128T111411_N0206_R137_T30UVB_20171128T130743',
#   'properties': {'datetime': '2017-11-28T11:14:12Z', 'eo:cloud_cover': 4.0}},
#  {'id': 'S2B_MSIL1C_20171123T111349_N0206_R137_T30UWB_20171123T132843',
#   'properties': {'datetime': '2017-11-23T11:16:29Z', 'eo:cloud_cover': 2.16}},
#  {'id': 'S2B_MSIL1C_20171123T111349_N0206_R137_T30UVB_20171123T132843',
#   'properties': {'datetime': '2017-11-23T11:16:29Z', 'eo:cloud_cover': 5.06}},
#  {'id': 'S2A_MSIL1C_20171108T111251_N0206_R137_T30UVB_20171108T132718',
#   'properties': {'datetime': '2017-11-08T11:12:50Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2A_MSIL1C_20171108T111251_N0206_R137_T30UWB_20171108T132718',
#   'properties': {'datetime': '2017-11-08T11:12:50Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2B_MSIL1C_20171027T112139_N0206_R037_T30UVB_20171027T145835',
#   'properties': {'datetime': '2017-10-27T11:25:51Z', 'eo:cloud_cover': 0.68}},
#  {'id': 'S2B_MSIL1C_20171027T112139_N0206_R037_T30UWB_20171027T145835',
#   'properties': {'datetime': '2017-10-27T11:25:51Z', 'eo:cloud_cover': 0.68}},
#  {'id': 'S2A_MSIL1C_20170922T112111_N0205_R037_T30UWB_20170922T112655',
#   'properties': {'datetime': '2017-09-22T11:26:55Z', 'eo:cloud_cover': 7.78}},
#  {'id': 'S2A_MSIL1C_20170724T112121_N0205_R037_T30UVB_20170724T112433',
#   'properties': {'datetime': '2017-07-24T11:24:33Z', 'eo:cloud_cover': 5.87}},
#  {'id': 'S2B_MSIL1C_20170706T110619_N0205_R137_T30UVB_20170706T110942',
#   'properties': {'datetime': '2017-07-06T11:09:42Z', 'eo:cloud_cover': 7.31}},
#  {'id': 'S2A_MSIL1C_20170701T111051_N0205_R137_T30UVB_20170701T111048',
#   'properties': {'datetime': '2017-07-01T11:10:48Z', 'eo:cloud_cover': 1.52}},
#  {'id': 'S2A_MSIL1C_20170621T110651_N0205_R137_T30UVB_20170621T111222',
#   'properties': {'datetime': '2017-06-21T11:12:22Z', 'eo:cloud_cover': 8.73}},
#  {'id': 'S2A_MSIL1C_20170601T110651_N0205_R137_T30UWB_20170601T111225',
#   'properties': {'datetime': '2017-06-01T11:12:25Z', 'eo:cloud_cover': 9.81}},
#  {'id': 'S2A_MSIL1C_20170525T112121_N0205_R037_T30UVB_20170525T112434',
#   'properties': {'datetime': '2017-05-25T11:24:34Z', 'eo:cloud_cover': 0.11}},
#  {'id': 'S2A_MSIL1C_20170525T112121_N0205_R037_T30UWB_20170525T112434',
#   'properties': {'datetime': '2017-05-25T11:24:34Z', 'eo:cloud_cover': 6.08}},
#  {'id': 'S2A_MSIL1C_20170402T110651_N0204_R137_T30UWB_20170402T110647',
#   'properties': {'datetime': '2017-04-02T11:06:47Z', 'eo:cloud_cover': 6.85}},
#  {'id': 'S2A_MSIL1C_20170313T110831_N0204_R137_T30UVB_20170313T111212',
#   'properties': {'datetime': '2017-03-13T11:12:12Z', 'eo:cloud_cover': 5.26}},
#  {'id': 'S2A_MSIL1C_20170125T112331_N0204_R037_T30UVB_20170125T112333',
#   'properties': {'datetime': '2017-01-25T11:23:33Z', 'eo:cloud_cover': 0.01}},
#  {'id': 'S2A_MSIL1C_20170105T112441_N0204_R037_T30UWB_20170105T112439',
#   'properties': {'datetime': '2017-01-05T11:24:39Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2A_MSIL1C_20170102T111442_N0204_R137_T30UVB_20170102T111441',
#   'properties': {'datetime': '2017-01-02T11:14:41Z', 'eo:cloud_cover': 0.31}},
#  {'id': 'S2A_MSIL1C_20170102T111442_N0204_R137_T30UWB_20170102T111441',
#   'properties': {'datetime': '2017-01-02T11:14:41Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2A_OPER_PRD_MSIL1C_PDMC_20161106T184008_R037_V20161106T112242_20161106T112242',
#   'properties': {'datetime': '2016-11-06T11:23:07Z', 'eo:cloud_cover': 1.49}},
#  {'id': 'S2A_MSIL1C_20161106T112242_N0204_R037_T30UVB_20161106T112307',
#   'properties': {'datetime': '2016-11-06T11:23:07Z', 'eo:cloud_cover': 1.49}},
#  {'id': 'S2A_OPER_PRD_MSIL1C_PDMC_20160815T205931_R137_V20160815T110652_20160815T110803',
#   'properties': {'datetime': '2016-08-15T11:08:03Z', 'eo:cloud_cover': 8.43}},
#  {'id': 'S2A_OPER_PRD_MSIL1C_PDMC_20160719T185327_R037_V20160719T112117_20160719T112117',
#   'properties': {'datetime': '2016-07-19T11:21:17Z', 'eo:cloud_cover': 0.01}},
#  {'id': 'S2A_OPER_PRD_MSIL1C_PDMC_20160719T185327_R037_V20160719T112117_20160719T112117',
#   'properties': {'datetime': '2016-07-19T11:21:17Z', 'eo:cloud_cover': 0.0}},
#  {'id': 'S2A_OPER_PRD_MSIL1C_PDMC_20161210T214034_R137_V20151020T111102_20151020T111102',
#   'properties': {'datetime': '2015-10-20T11:11:03Z', 'eo:cloud_cover': 8.06}},
#  {'id': 'S2A_OPER_PRD_MSIL1C_PDMC_20161210T214034_R137_V20151020T111102_20151020T111102',
#   'properties': {'datetime': '2015-10-20T11:11:03Z', 'eo:cloud_cover': 8.46}},
#  {'id': 'S2A_OPER_PRD_MSIL1C_PDMC_20161103T183715_R137_V20150930T111106_20150930T111106',
#   'properties': {'datetime': '2015-09-30T11:11:02Z', 'eo:cloud_cover': 0.33}},
#  {'id': 'S2A_OPER_PRD_MSIL1C_PDMC_20161103T183715_R137_V20150930T111106_20150930T111106',
#   'properties': {'datetime': '2015-09-30T11:11:02Z', 'eo:cloud_cover': 0.45}},
#  {'id': 'S2A_OPER_PRD_MSIL1C_PDMC_20160720T165432_R137_V20150910T111633_20150910T111633',
#   'properties': {'datetime': '2015-09-10T11:16:33Z', 'eo:cloud_cover': 0.39}},
#  {'id': 'S2A_OPER_PRD_MSIL1C_PDMC_20160720T165432_R137_V20150910T111633_20150910T111633',
#   'properties': {'datetime': '2015-09-10T11:16:33Z', 'eo:cloud_cover': 0.14}},
#  {'id': 'S2A_OPER_PRD_MSIL1C_PDMC_20160814T234057_R037_V20150725T112046_20150725T112540',
#   'properties': {'datetime': '2015-07-25T11:25:40Z', 'eo:cloud_cover': 8.54}},
#  {'id': 'S2A_OPER_PRD_MSIL1C_PDMC_20160530T104048_R037_V20150725T112540_20150725T112540',
#   'properties': {'datetime': '2015-07-25T11:25:40Z', 'eo:cloud_cover': 8.14}}]

# %%
# Find the unique date and time values between the two geographical tiles 30UVB and 30UWB
time_difference = dt.timedelta(hours=1)

all_timestamps = search_iterator.get_timestamps()
unique_acquisitions = filter_times(all_timestamps, time_difference)

print("Number of unique dates: ", len(unique_acquisitions))
print("Unique dates: ", unique_acquisitions)
# Out:
# Number of unique dates:  153
# Unique dates:  [datetime.datetime(2015, 7, 25, 11, 25, 40, tzinfo=tzlocal()), datetime.datetime(2015, 9, 10, 11, 16, 33, tzinfo=tzlocal()), datetime.datetime(2015, 9, 30, 11, 11, 2, tzinfo=tzlocal()), datetime.datetime(2015, 10, 20, 11, 11, 3, tzinfo=tzlocal()), datetime.datetime(2016, 7, 19, 11, 21, 17, tzinfo=tzlocal()), datetime.datetime(2016, 8, 15, 11, 8, 3, tzinfo=tzlocal()), datetime.datetime(2016, 11, 6, 11, 23, 7, tzinfo=tzlocal()), datetime.datetime(2017, 1, 2, 11, 14, 41, tzinfo=tzlocal()), datetime.datetime(2017, 1, 5, 11, 24, 39, tzinfo=tzlocal()), datetime.datetime(2017, 1, 25, 11, 23, 33, tzinfo=tzlocal()), datetime.datetime(2017, 3, 13, 11, 12, 12, tzinfo=tzlocal()), datetime.datetime(2017, 4, 2, 11, 6, 47, tzinfo=tzlocal()), datetime.datetime(2017, 5, 25, 11, 24, 34, tzinfo=tzlocal()), datetime.datetime(2017, 6, 1, 11, 12, 25, tzinfo=tzlocal()), datetime.datetime(2017, 6, 21, 11, 12, 22, tzinfo=tzlocal()), datetime.datetime(2017, 7, 1, 11, 10, 48, tzinfo=tzlocal()), datetime.datetime(2017, 7, 6, 11, 9, 42, tzinfo=tzlocal()), datetime.datetime(2017, 7, 24, 11, 24, 33, tzinfo=tzlocal()), datetime.datetime(2017, 9, 22, 11, 26, 55, tzinfo=tzlocal()), datetime.datetime(2017, 10, 27, 11, 25, 51, tzinfo=tzlocal()), datetime.datetime(2017, 11, 8, 11, 12, 50, tzinfo=tzlocal()), datetime.datetime(2017, 11, 23, 11, 16, 29, tzinfo=tzlocal()), datetime.datetime(2017, 11, 28, 11, 14, 12, tzinfo=tzlocal()), datetime.datetime(2017, 12, 1, 11, 26, 42, tzinfo=tzlocal()), datetime.datetime(2017, 12, 8, 11, 15, 49, tzinfo=tzlocal()), datetime.datetime(2017, 12, 16, 11, 24, 45, tzinfo=tzlocal()), datetime.datetime(2017, 12, 18, 11, 14, 49, tzinfo=tzlocal()), datetime.datetime(2018, 1, 10, 11, 24, 27, tzinfo=tzlocal()), datetime.datetime(2018, 2, 24, 11, 22, 28, tzinfo=tzlocal()), datetime.datetime(2018, 4, 20, 11, 26, 11, tzinfo=tzlocal()), datetime.datetime(2018, 5, 5, 11, 23, 4, tzinfo=tzlocal()), datetime.datetime(2018, 5, 7, 11, 8, 35, tzinfo=tzlocal()), datetime.datetime(2018, 5, 15, 11, 21, 16, tzinfo=tzlocal()), datetime.datetime(2018, 6, 11, 11, 7, 4, tzinfo=tzlocal()), datetime.datetime(2018, 6, 26, 11, 14, 13, tzinfo=tzlocal()), datetime.datetime(2018, 6, 29, 11, 25, 37, tzinfo=tzlocal()), datetime.datetime(2018, 7, 6, 11, 9, 18, tzinfo=tzlocal()), datetime.datetime(2018, 7, 9, 11, 24, 55, tzinfo=tzlocal()), datetime.datetime(2018, 7, 21, 11, 9, 39, tzinfo=tzlocal()), datetime.datetime(2018, 7, 24, 11, 23, 35, tzinfo=tzlocal()), datetime.datetime(2018, 7, 26, 11, 16, 15, tzinfo=tzlocal()), datetime.datetime(2018, 7, 31, 11, 14, 37, tzinfo=tzlocal()), datetime.datetime(2018, 8, 5, 11, 15, 14, tzinfo=tzlocal()), datetime.datetime(2018, 8, 25, 11, 16, 24, tzinfo=tzlocal()), datetime.datetime(2018, 9, 9, 11, 13, 19, tzinfo=tzlocal()), datetime.datetime(2018, 9, 24, 11, 14, 16, tzinfo=tzlocal()), datetime.datetime(2018, 9, 27, 11, 23, 30, tzinfo=tzlocal()), datetime.datetime(2018, 10, 9, 11, 9, 42, tzinfo=tzlocal()), datetime.datetime(2018, 10, 19, 11, 10, 50, tzinfo=tzlocal()), datetime.datetime(2018, 10, 22, 11, 21, 13, tzinfo=tzlocal()), datetime.datetime(2018, 10, 29, 11, 11, 52, tzinfo=tzlocal()), datetime.datetime(2018, 11, 11, 11, 27, 5, tzinfo=tzlocal()), datetime.datetime(2018, 11, 18, 11, 17, 3, tzinfo=tzlocal()), datetime.datetime(2018, 11, 26, 11, 26, 55, tzinfo=tzlocal()), datetime.datetime(2019, 1, 17, 11, 17, 6, tzinfo=tzlocal()), datetime.datetime(2019, 2, 14, 11, 27, 4, tzinfo=tzlocal()), datetime.datetime(2019, 2, 24, 11, 36, 54, tzinfo=tzlocal()), datetime.datetime(2019, 2, 26, 11, 17, 13, tzinfo=tzlocal()), datetime.datetime(2019, 3, 26, 11, 27, 9, tzinfo=tzlocal()), datetime.datetime(2019, 3, 28, 11, 20, 11, tzinfo=tzlocal()), datetime.datetime(2019, 4, 20, 11, 29, 56, tzinfo=tzlocal()), datetime.datetime(2019, 6, 29, 11, 27, 11, tzinfo=tzlocal()), datetime.datetime(2019, 7, 4, 11, 27, 12, tzinfo=tzlocal()), datetime.datetime(2019, 7, 6, 11, 17, 19, tzinfo=tzlocal()), datetime.datetime(2019, 7, 16, 11, 17 ...

# %%
## Define the evaluation function that will be passed in the request
# Request will return:
# - Blue (B02), Green (B03), Red (B04), NIR (B08) and SWIR (B11) bands + CLM (cloud mask raster)
# - Sentinel-2 metadata

evalscript_all_bands = """
    //VERSION=3
    function setup() {
        return {
            input: [{
                bands: ["B02", "B03", "B04", "B08", "B11", "CLM"],
                units: "DN"}],
            output: {
                bands: 6,
                sampleType: "INT16"
            },
            mosaicking: Mosaicking.TILE
        };
    }

    function updateOutputMetadata(scenes, inputMetadata, outputMetadata) {
        outputMetadata.userData = { "norm_factor":  inputMetadata.normalizationFactor,
                                    "scenes":  JSON.stringify(scenes)}
    }

    function evaluatePixel(sample) {
        return [sample[0].B02,
                sample[0].B03,
                sample[0].B04,
                sample[0].B08,
                sample[0].B11,
                sample[0].CLM];
    }
"""

# %%
# Sentinel Hub request script
# Key parameters to change:
# - data_folder (where the files will be saved),
# - data_collection (to return S2 L1C - DataCollection.SENTINEL2_L1C, S2 L2A - DataCollection.SENTINEL2_L2A)

process_requests = []

for timestamp in unique_acquisitions:
    request = SentinelHubRequest(
        data_folder="/content/drive/MyDrive/FINAL_project/full_lyme_regis_S2_L1C",
        evalscript=evalscript_all_bands,
        input_data=[
            SentinelHubRequest.input_data(
                data_collection=DataCollection.SENTINEL2_L1C,
                time_interval=(timestamp - time_difference, timestamp + time_difference),
                mosaicking_order=MosaickingOrder.LEAST_CC,
            )
        ],
        responses=[SentinelHubRequest.output_response("default", MimeType.TIFF),
                    SentinelHubRequest.output_response("userdata", MimeType.JSON)],
        bbox=landslide_bbox,
        size=landslide_size,
        config=config,
    )

    process_requests.append(request)

# %%
# %%time
# Submit the request and download the tiles
downloaded_data = [request.get_data(save_data=True) for request in process_requests]

# %%
# # Load one of the tiles and visualize
image = process_requests[0].get_data()[0]['default.tif']
print(image.shape)
plot_image(image[:, :, [2, 1, 0]], factor=3.5 / 1e4, clip_range=(0, 1))

# %%
## Extract the data and meta data from the tar zipped folder
input_lyme_regis_path = "/content/drive/MyDrive/FINAL_project/full_lyme_regis_S2_L1C"

folder_ids = []

for root, dirs, files in os.walk(input_lyme_regis_path):
  for file in files:
    if file.startswith("response"):
      folder_id = root.rsplit('/', 1)[1]
      print(folder_id)
      output_path = os.path.join(root, f'response_{folder_id}')
      file_tar = tarfile.open(os.path.join(root,file))
      file_tar.extractall(output_path) # specify which folder to extract to
      file_tar.close()

      folder_ids.append(folder_id)

print("Check the number of extracted folders: ", len(folder_ids))
